# %% [markdown]
# ### **Connect With Me in Linkedin** :- https://www.linkedin.com/in/dheerajkumar1997/

# %% [markdown]
# ======================================================================================================================
# # 1.1Installing PyCaret
# <br>
# <br>
#
# The first step to get started with **PyCaret is to install PyCaret**. Installation is easy and will only take a few minutes. Follow the instructions below:
# <br>
# <br>
# **Installing PyCaret** in **Local Jupyter Notebook**
# <br>
# <br>
# **pip install pycaret**
# <br>
#
# **Installing PyCaret on Google Colab or Azure Notebooks
# br<>
# !pip install pycaret**
# <br>
# <br>
#
# =======================================================================================================================
#
# # 1.2 Pre-Requisites
# <br>
# <br>
#
# **(i)** Python 3.x
# <br>
#
# **(ii)** Latest version of pycaret
# <br>
#
# **(iii)** Internet connection to load data from pycaret's repository
# <br>
#
# **(iv)** Basic Knowledge of Binary Classification

# %% [markdown]
# ======================================================================================================================
# # 1.3 What is Binary Classification?
# <br>
# <br>
#
# **1)  Binary classification** is a **supervised machine learning techniqu**e where the goal is to predict categorical class labels which are discrete and unoredered such as **Pass/Fail, Positive/Negative, Default/Not-Default** etc. A few real world use cases for binary classification are listed below:
# <br>
# <br>
#
# **2)  Medical testing** to determine **if a patient has a certain disease or not** - the classification property is the presence of the disease.
# A "pass or fail" test method or quality control in factories, i.e. deciding if a specification has or has not been met – a go/no-go classification.
# Information retrieval, namely deciding whether a page or an article should be in the result set of a search or not – the classification property is the relevance of the article, or the usefulness to the user.

# %% [markdown]
# ========================================================================================================================
# # 1.4 Overview of the Classification Module in PyCaret
# <br>
# <br>
#
# **1) PyCaret's classification module** (pycaret.classification) is a **supervised machine learning module** which is used for **classifying the elements** into a **binary groups** based on various techniques and algorithms. Some common **use cases of binary classification problems** include predicting **customer default (yes or no), customer churn (customer will leave or stay), disease found (positive or negative)**.
# <br>
# <br>
#
# **2)** The **PyCaret classification module** can be used for binary or **multi-class classification problems**. It has over 18 algorithms and 14 plots to analyze the performance of models. Be it hyper-parameter tuning, ensembling or advanced techniques like stacking, PyCaret's classification module has it all.

# %% [markdown]
# ======================================================================================================================
# ### Dataset Details
# <br>
# <br>
#
# **ID**: ID of each client
# <br>
# <br>
# **LIMIT_BAL**: Amount of given credit in NT dollars (includes individual and family/supplementary credit)
# <br>
# <br>
# **SEX**: Gender (1=male, 2=female)
# <br>
# <br>
# **EDUCATION**: (1=graduate school, 2=university, 3=high school, 4=others, 5=unknown, 6=unknown)
# <br>
# <br>
# **MARRIAGE**: Marital status (1=married, 2=single, 3=others)
# <br>
# <br>
# **AGE**: Age in years
# <br>
# <br>
# **PAY_0 to PAY_6**: Repayment status by n months ago (PAY_0 = last month ... PAY_6 = 6 months ago) (Labels: -1=pay duly, 1=payment delay for one month, 2=payment delay for two months, ... 8=payment delay for eight months, 9=payment delay for nine months and above)
# <br>
# <br>
# **BILL_AMT1 to BILL_AMT6**: Amount of bill statement by n months ago ( BILL_AMT1 = last_month .. BILL_AMT6 = 6 months ago)
# <br>
# <br>
# **PAY_AMT1 to PAY_AMT6**: Amount of payment by n months ago ( BILL_AMT1 = last_month .. BILL_AMT6 = 6 months ago)
# <br>
# <br>
# **default**: Default payment (1=yes, 0=no) Target Column

# %% [markdown]
# # Getting Data

# %%
from pycaret.datasets import get_data
dataset = get_data('credit')
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1      90000    2          2         2   34      0      0      0      0
# 2      50000    2          2         1   37      0      0      0      0
# 3      50000    1          2         1   57     -1      0     -1      0
# 4      50000    1          1         2   37      0      0      0      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -2  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1      0  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 2      0  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 3      0  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
# 4      0  ...    19394.0    19619.0    20024.0    2500.0    1815.0     657.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default
# ...

# %%
dataset.shape

# %%
data = dataset.sample(frac=0.95, random_state=786)
data_unseen = dataset.drop(data.index).reset_index(drop=True)
data.reset_index(drop=True, inplace=True)

print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
# Out:
# Data for Modeling: (22800, 24)
# Unseen Data For Predictions: (1200, 24)

# %% [markdown]
# # Setting up Environment in PyCaret

# %%
from pycaret.classification import *
exp_clf101 = setup(data = data, target = 'default', session_id=123)
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T
rf)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=10, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=2, min_samples_split=10,
#                        min_weight_fraction_leaf=0.0, n_estimators=70,
#                        n_jobs=None, oob_score=False, random_state=123,
#                        verbose=0, warm_start=False)

# %% [markdown]
# # Plot a Model
#
# ## AUC Plot

# %%
plot_model(tuned_rf, plot = 'auc')

# %% [markdown]
# ## Precision-Recall Curve

# %%
plot_model(tuned_rf, plot = 'pr')

# %% [markdown]
# ## Feature Importance Plot

# %%
plot_model(tuned_rf, plot='feature')

# %% [markdown]
# ## Confusion Matrix

# %%
plot_model(tuned_rf, plot = 'confusion_matrix')

# %%
evaluate_model(tuned_rf)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %% [markdown]
# # Predict on test / hold-out Sample

# %%
predict_model(tuned_rf);
# Out:
#                       Model  Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0  Random Forest Classifier    0.8126  0.7538  0.3212  0.6559  0.4312  0.3345

# %% [markdown]
# # Finalize Model for Deployment

# %%
final_rf = finalize_model(tuned_rf)

# %%
print(final_rf)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=10, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=2, min_samples_split=10,
#                        min_weight_fraction_leaf=0.0, n_estimators=70,
#                        n_jobs=None, oob_score=False, random_state=123,
#                        verbose=0, warm_start=False)

# %%
predict_model(final_rf);
# Out:
#                       Model  Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0  Random Forest Classifier    0.8361  0.8189  0.3681  0.7715  0.4984  0.4148

# %% [markdown]
# # Predict on Unseen Data

# %%
unseen_predictions = predict_model(final_rf, data=data_unseen)
unseen_predictions.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0     100000    2          2         2   23      0     -1     -1      0
# 1     380000    1          2         2   32     -1     -1     -1     -1
# 2     200000    2          2         1   32     -1     -1     -1     -1
# 3     200000    1          1         1   53      2      2      2      2
# 4     240000    1          1         2   41      1     -1     -1      0
#
#    PAY_5  ...  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  \
# 0      0  ...      567.0     380.0     601.0       0.0     581.0    1687.0
# 1     -1  ...    11873.0   21540.0   15138.0   24677.0   11851.0   11875.0
# 2      2  ...     3151.0    5818.0      15.0    9102.0      17.0    3165.0
# 3      2  ...   149531.0    6300.0    5500.0    5500.0    5500.0    5000.0
# 4      0  ...     1737.0    2622.0    3301.0       0.0     360.0    1737.0
#
#    PAY_AMT6  default  Label   Score
# 0    1542.0        0      0  0.1917
# ...

# %% [markdown]
# # Saving the model

# %%
save_model(final_rf,'Final RF Model 08Feb2020')
# Out:
# Transformation Pipeline and Model Succesfully Saved

# %% [markdown]
# # Loading the saved model

# %%
saved_final_rf = load_model('Final RF Model 08Feb2020')
# Out:
# Transformation Pipeline and Model Sucessfully Loaded

# %%
new_prediction = predict_model(saved_final_rf, data=data_unseen)
new_prediction.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0     100000    2          2         2   23      0     -1     -1      0
# 1     380000    1          2         2   32     -1     -1     -1     -1
# 2     200000    2          2         1   32     -1     -1     -1     -1
# 3     200000    1          1         1   53      2      2      2      2
# 4     240000    1          1         2   41      1     -1     -1      0
#
#    PAY_5  ...  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  \
# 0      0  ...      567.0     380.0     601.0       0.0     581.0    1687.0
# 1     -1  ...    11873.0   21540.0   15138.0   24677.0   11851.0   11875.0
# 2      2  ...     3151.0    5818.0      15.0    9102.0      17.0    3165.0
# 3      2  ...   149531.0    6300.0    5500.0    5500.0    5500.0    5000.0
# 4      0  ...     1737.0    2622.0    3301.0       0.0     360.0    1737.0
#
#    PAY_AMT6  default  Label   Score
# 0    1542.0        0      0  0.1917
# ...

# %% [markdown]
# # Ensemble a Model

# %%
dt = create_model('dt')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.7325  0.6213  0.4221  0.4005  0.4110  0.2381
# 1       0.7237  0.6199  0.4306  0.3878  0.4081  0.2285
# 2       0.7400  0.6361  0.4504  0.4184  0.4338  0.2654
# 3       0.7155  0.5984  0.3853  0.3646  0.3747  0.1907
# 4       0.7375  0.6175  0.4023  0.4057  0.4040  0.2356
# 5       0.7356  0.6376  0.4618  0.4127  0.4358  0.2639
# 6       0.7237  0.6210  0.4363  0.3889  0.4112  0.2315
# 7       0.7387  0.6365  0.4533  0.4167  0.4342  0.2647
# 8       0.7262  0.6062  0.3909  0.3833  0.3871  0.2108
# 9       0.7210  0.6030  0.3881  0.3743  0.3811  0.2011
# Mean    0.7294  0.6197  0.4221  0.3953  0.4081  0.2330
# SD      0.0081  0.0134  0.0274  0.0175  0.0211  0.0252

# %% [markdown]
# # Bagging

# %%
bagged_dt = ensemble_model(dt)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.8070  0.7430  0.3654  0.6056  0.4558  0.3472
# 1       0.8008  0.7249  0.3144  0.5936  0.4111  0.3046
# 2       0.8164  0.7797  0.4193  0.6271  0.5025  0.3954
# 3       0.7989  0.7063  0.3399  0.5769  0.4278  0.3156
# 4       0.8083  0.7181  0.3258  0.6284  0.4291  0.3275
# 5       0.8139  0.7447  0.3144  0.6687  0.4277  0.3334
# 6       0.7982  0.7229  0.3229  0.5787  0.4145  0.3043
# 7       0.8158  0.7613  0.3626  0.6497  0.4655  0.3648
# 8       0.8089  0.7352  0.3654  0.6143  0.4583  0.3512
# 9       0.8025  0.7607  0.3456  0.5922  0.4365  0.3267
# Mean    0.8071  0.7397  0.3476  0.6135  0.4429  0.3371
# SD      0.0065  0.0216  0.0306  0.0287  0.0264  0.0270

# %%
print(bagged_dt)
# Out:
# BaggingClassifier(base_estimator=DecisionTreeClassifier(ccp_alpha=0.0,
#                                                         class_weight=None,
#                                                         criterion='gini',
#                                                         max_depth=None,
#                                                         max_features=None,
#                                                         max_leaf_nodes=None,
#                                                         min_impurity_decrease=0.0,
#                                                         min_impurity_split=None,
#                                                         min_samples_leaf=1,
#                                                         min_samples_split=2,
#                                                         min_weight_fraction_leaf=0.0,
#                                                         presort='deprecated',
# ...

# %% [markdown]
# # Boosting

# %%
boosted_dt = ensemble_model(dt, method = 'Boosting')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.7694  0.7066  0.4023  0.4749  0.4356  0.2919
# 1       0.7907  0.6917  0.2890  0.5514  0.3792  0.2678
# 2       0.7838  0.6973  0.3173  0.5185  0.3937  0.2713
# 3       0.7563  0.6325  0.3314  0.4333  0.3756  0.2275
# 4       0.7845  0.7015  0.3144  0.5211  0.3922  0.2708
# 5       0.7920  0.6956  0.3569  0.5455  0.4315  0.3109
# 6       0.7807  0.7255  0.3569  0.5060  0.4186  0.2884
# 7       0.7863  0.6983  0.2975  0.5303  0.3811  0.2642
# 8       0.7914  0.7144  0.3909  0.5391  0.4532  0.3283
# 9       0.7705  0.6628  0.2351  0.4637  0.3120  0.1916
# Mean    0.7806  0.6926  0.3292  0.5084  0.3973  0.2713
# SD      0.0111  0.0253  0.0475  0.0370  0.0382  0.0372

# %%
bagged_dt2 = ensemble_model(dt, n_estimators=20)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.8127  0.7610  0.3626  0.6337  0.4613  0.3579
# 1       0.8164  0.7589  0.3513  0.6596  0.4584  0.3600
# 2       0.8208  0.7950  0.4278  0.6426  0.5136  0.4091
# 3       0.8033  0.7339  0.3626  0.5899  0.4491  0.3376
# 4       0.8133  0.7399  0.3683  0.6341  0.4659  0.3623
# 5       0.8202  0.7672  0.3541  0.6793  0.4655  0.3701
# 6       0.8020  0.7351  0.3343  0.5930  0.4275  0.3189
# 7       0.8158  0.7725  0.3711  0.6453  0.4712  0.3694
# 8       0.8170  0.7525  0.3909  0.6419  0.4859  0.3825
# 9       0.8063  0.7688  0.3683  0.6019  0.4569  0.3473
# Mean    0.8128  0.7585  0.3691  0.6321  0.4656  0.3615
# SD      0.0064  0.0180  0.0240  0.0276  0.0215  0.0233

# %%
tuned_bagged_dt = tune_model('dt', ensemble=True, method='Bagging')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.8258  0.7777  0.3428  0.7246  0.4654  0.3769
# 1       0.8189  0.7825  0.3201  0.6975  0.4388  0.3481
# 2       0.8158  0.8001  0.3286  0.6705  0.4411  0.3459
# 3       0.8183  0.7626  0.3314  0.6842  0.4466  0.3532
# 4       0.8239  0.7687  0.3314  0.7222  0.4544  0.3662
# 5       0.8221  0.7857  0.3399  0.7018  0.4580  0.3666
# 6       0.8202  0.7485  0.3258  0.7012  0.4449  0.3543
# 7       0.8308  0.7811  0.3314  0.7748  0.4643  0.3824
# 8       0.8202  0.7518  0.3201  0.7062  0.4405  0.3510
# 9       0.8169  0.7713  0.3371  0.6723  0.4491  0.3535
# Mean    0.8213  0.7730  0.3309  0.7055  0.4503  0.3598
# SD      0.0043  0.0150  0.0073  0.0289  0.0093  0.0119

# %%
print(tuned_bagged_dt)
# Out:
# BaggingClassifier(base_estimator=DecisionTreeClassifier(ccp_alpha=0.0,
#                                                         class_weight=None,
#                                                         criterion='entropy',
#                                                         max_depth=4,
#                                                         max_features=None,
#                                                         max_leaf_nodes=None,
#                                                         min_impurity_decrease=0.0,
#                                                         min_impurity_split=None,
#                                                         min_samples_leaf=4,
#                                                         min_samples_split=2,
#                                                         min_weight_fraction_leaf=0.0,
#                                                         presort='deprecated',
# ...

# %% [markdown]
# # Blending

# %%
blend_hard = blend_models()
# Out:
#       Accuracy  AUC  Recall   Prec.      F1   Kappa
# 0       0.8233  0.0  0.3343  0.7152  0.4556  0.3663
# 1       0.8208  0.0  0.3314  0.7006  0.4500  0.3589
# 2       0.8221  0.0  0.3654  0.6825  0.4760  0.3804
# 3       0.8164  0.0  0.3258  0.6765  0.4398  0.3457
# 4       0.8227  0.0  0.3314  0.7134  0.4526  0.3633
# 5       0.8202  0.0  0.3513  0.6813  0.4636  0.3685
# 6       0.8214  0.0  0.3456  0.6932  0.4612  0.3683
# 7       0.8289  0.0  0.3314  0.7597  0.4615  0.3780
# 8       0.8214  0.0  0.3343  0.7024  0.4530  0.3620
# 9       0.8138  0.0  0.3598  0.6414  0.4610  0.3590
# Mean    0.8211  0.0  0.3411  0.6966  0.4574  0.3650
# SD      0.0038  0.0  0.0129  0.0293  0.0092  0.0094

# %%
blend_soft = blend_models(method = 'soft')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.8189  0.7766  0.3286  0.6905  0.4453  0.3530
# 1       0.8152  0.7814  0.3229  0.6706  0.4359  0.3412
# 2       0.8233  0.8148  0.4674  0.6371  0.5392  0.4331
# 3       0.8202  0.7694  0.3399  0.6897  0.4554  0.3623
# 4       0.8158  0.7659  0.3258  0.6725  0.4389  0.3443
# 5       0.8233  0.7944  0.3569  0.6961  0.4719  0.3788
# 6       0.8152  0.7551  0.3201  0.6726  0.4338  0.3396
# 7       0.8283  0.7897  0.3569  0.7283  0.4791  0.3904
# 8       0.8195  0.7500  0.3371  0.6879  0.4525  0.3592
# 9       0.8025  0.7749  0.3116  0.6044  0.4112  0.3068
# Mean    0.8182  0.7772  0.3467  0.6750  0.4563  0.3609
# SD      0.0066  0.0182  0.0426  0.0322  0.0332  0.0324

# %%
gbc = create_model('gbc', verbose = False)
dt = create_model('dt', verbose = False)
lightgbm = create_model('lightgbm', verbose = False)
xgboost = create_model('xgboost', verbose = False)

# %%
blend_specific_hard = blend_models(estimator_list = [gbc, dt, lightgbm, xgboost], method = 'hard')
# Out:
#       Accuracy  AUC  Recall   Prec.      F1   Kappa
# 0       0.8258  0.0  0.3456  0.7219  0.4674  0.3784
# 1       0.8195  0.0  0.3399  0.6857  0.4545  0.3608
# 2       0.8221  0.0  0.3739  0.6769  0.4818  0.3849
# 3       0.8183  0.0  0.3428  0.6760  0.4549  0.3596
# 4       0.8258  0.0  0.3598  0.7095  0.4774  0.3861
# 5       0.8214  0.0  0.3598  0.6828  0.4712  0.3760
# 6       0.8195  0.0  0.3399  0.6857  0.4545  0.3608
# 7       0.8358  0.0  0.3711  0.7661  0.5000  0.4156
# 8       0.8227  0.0  0.3428  0.7035  0.4610  0.3696
# 9       0.8169  0.0  0.3683  0.6533  0.4710  0.3706
# Mean    0.8228  0.0  0.3544  0.6961  0.4694  0.3762
# SD      0.0052  0.0  0.0129  0.0297  0.0137  0.0160

# %% [markdown]
# # Stacking

# %%
stack_soft = stack_models([gbc, dt, lightgbm, xgboost])
# Out:
#       Accuracy     AUC  Recall  Prec.      F1   Kappa
# 0       0.7788  0.6546  0.0000  0.000  0.0000  0.0000
# 1       0.7788  0.6364  0.0000  0.000  0.0000  0.0000
# 2       0.7776  0.6834  0.0028  0.250  0.0056  0.0006
# 3       0.7788  0.6617  0.0000  0.000  0.0000  0.0000
# 4       0.7788  0.6435  0.0000  0.000  0.0000  0.0000
# 5       0.7788  0.6707  0.0000  0.000  0.0000  0.0000
# 6       0.7788  0.6334  0.0000  0.000  0.0000  0.0000
# 7       0.7782  0.6564  0.0000  0.000  0.0000 -0.0013
# 8       0.7788  0.6335  0.0000  0.000  0.0000  0.0000
# 9       0.7787  0.6377  0.0000  0.000  0.0000  0.0000
# Mean    0.7786  0.6511  0.0003  0.025  0.0006 -0.0001
# SD      0.0004  0.0163  0.0008  0.075  0.0017  0.0004

# %%
stack_hard = stack_models([gbc, dt, lightgbm, xgboost], method='hard')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.7782  0.6545  0.0000  0.0000  0.0000 -0.0013
# 1       0.7794  0.6405  0.0028  1.0000  0.0056  0.0044
# 2       0.7782  0.6833  0.0028  0.3333  0.0056  0.0019
# 3       0.7788  0.6566  0.0000  0.0000  0.0000  0.0000
# 4       0.7788  0.6435  0.0000  0.0000  0.0000  0.0000
# 5       0.7782  0.6696  0.0000  0.0000  0.0000 -0.0013
# 6       0.7788  0.6342  0.0000  0.0000  0.0000  0.0000
# 7       0.7794  0.6565  0.0028  1.0000  0.0056  0.0044
# 8       0.7788  0.6334  0.0000  0.0000  0.0000  0.0000
# 9       0.7787  0.6373  0.0000  0.0000  0.0000  0.0000
# Mean    0.7787  0.6509  0.0008  0.2333  0.0017  0.0008
# SD      0.0004  0.0155  0.0013  0.3958  0.0026  0.0020

# %%
stack_soft2 = stack_models([gbc, dt, lightgbm], meta_model=xgboost)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.8170  0.7799  0.3881  0.6432  0.4841  0.3811
# 1       0.8233  0.7937  0.3683  0.6878  0.4797  0.3848
# 2       0.8164  0.8203  0.3909  0.6389  0.4851  0.3811
# 3       0.8158  0.7744  0.3711  0.6453  0.4712  0.3694
# 4       0.8233  0.7837  0.3711  0.6859  0.4816  0.3863
# 5       0.8221  0.7941  0.3909  0.6667  0.4929  0.3937
# 6       0.8158  0.7638  0.3796  0.6411  0.4769  0.3739
# 7       0.8315  0.7963  0.3824  0.7258  0.5009  0.4110
# 8       0.8208  0.7658  0.3711  0.6718  0.4781  0.3806
# 9       0.8119  0.7824  0.3739  0.6256  0.4681  0.3625
# Mean    0.8198  0.7854  0.3788  0.6632  0.4819  0.3824
# SD      0.0053  0.0158  0.0084  0.0289  0.0092  0.0127

# %%
stack_soft_plot = stack_models([gbc,dt,lightgbm,xgboost], plot=True)
# Out:
#       Accuracy     AUC  Recall  Prec.      F1   Kappa
# 0       0.7788  0.6546  0.0000  0.000  0.0000  0.0000
# 1       0.7788  0.6364  0.0000  0.000  0.0000  0.0000
# 2       0.7776  0.6834  0.0028  0.250  0.0056  0.0006
# 3       0.7788  0.6617  0.0000  0.000  0.0000  0.0000
# 4       0.7788  0.6435  0.0000  0.000  0.0000  0.0000
# 5       0.7788  0.6707  0.0000  0.000  0.0000  0.0000
# 6       0.7788  0.6334  0.0000  0.000  0.0000  0.0000
# 7       0.7782  0.6564  0.0000  0.000  0.0000 -0.0013
# 8       0.7788  0.6335  0.0000  0.000  0.0000  0.0000
# 9       0.7787  0.6377  0.0000  0.000  0.0000  0.0000
# Mean    0.7786  0.6511  0.0003  0.025  0.0006 -0.0001
# SD      0.0004  0.0163  0.0008  0.075  0.0017  0.0004

# %% [markdown]
# # Model Calibration

# %%
rf = create_model('rf')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.8064  0.7435  0.3229  0.6196  0.4246  0.3218
# 1       0.8076  0.7488  0.3314  0.6223  0.4325  0.3295
# 2       0.8170  0.7576  0.3683  0.6533  0.4710  0.3707
# 3       0.8139  0.7175  0.3513  0.6458  0.4550  0.3544
# 4       0.8026  0.7199  0.2890  0.6145  0.3931  0.2930
# 5       0.8114  0.7446  0.3569  0.6300  0.4557  0.3520
# 6       0.8008  0.7286  0.3258  0.5897  0.4197  0.3113
# 7       0.8070  0.7502  0.3144  0.6271  0.4189  0.3181
# 8       0.8114  0.7262  0.3371  0.6398  0.4416  0.3410
# 9       0.8063  0.7428  0.3399  0.6122  0.4372  0.3315
# Mean    0.8084  0.7380  0.3337  0.6254  0.4349  0.3323
# SD      0.0048  0.0131  0.0216  0.0174  0.0213  0.0217

# %%
plot_model(rf, plot='calibration')

# %%
calibrated_rf = calibrate_model(rf)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.8214  0.7696  0.2975  0.7394  0.4242  0.3406
# 1       0.8214  0.7819  0.2805  0.7615  0.4099  0.3302
# 2       0.8127  0.8073  0.2833  0.6849  0.4008  0.3117
# 3       0.8139  0.7508  0.3088  0.6728  0.4233  0.3301
# 4       0.8064  0.7560  0.2550  0.6618  0.3681  0.2795
# 5       0.8164  0.7864  0.2861  0.7113  0.4081  0.3221
# 6       0.8095  0.7532  0.2833  0.6623  0.3968  0.3047
# 7       0.8208  0.7839  0.2776  0.7597  0.4066  0.3270
# 8       0.8164  0.7540  0.2890  0.7083  0.4105  0.3238
# 9       0.8044  0.7837  0.2720  0.6358  0.3810  0.2863
# Mean    0.8143  0.7727  0.2833  0.6998  0.4029  0.3156
# SD      0.0058  0.0179  0.0136  0.0413  0.0166  0.0189

# %%
plot_model(calibrated_rf, plot='calibration')

# %%
calibrated_rf_isotonic = calibrate_model(rf, method = 'isotonic')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.8208  0.7692  0.3059  0.7248  0.4303  0.3442
# 1       0.8227  0.7804  0.2918  0.7574  0.4213  0.3401
# 2       0.8139  0.8061  0.2975  0.6818  0.4142  0.3233
# 3       0.8108  0.7508  0.3088  0.6527  0.4192  0.3231
# 4       0.8051  0.7573  0.2663  0.6438  0.3768  0.2841
# 5       0.8170  0.7851  0.3059  0.6968  0.4252  0.3355
# 6       0.8139  0.7529  0.3003  0.6795  0.4165  0.3250
# 7       0.8208  0.7861  0.3003  0.7310  0.4257  0.3408
# 8       0.8177  0.7530  0.3088  0.6987  0.4283  0.3386
# 9       0.8069  0.7830  0.2946  0.6380  0.4031  0.3061
# Mean    0.8150  0.7724  0.2980  0.6905  0.4161  0.3261
# SD      0.0057  0.0177  0.0119  0.0374  0.0151  0.0178

# %%
plot_model(calibrated_rf_isotonic, plot='calibration')

# %% [markdown]
# # Predict on Test / Hold-Out Sample

# %%
predict_model(stack_soft);
# Out:
#                  Model  Accuracy     AUC  Recall  Prec.     F1   Kappa
# 0  Stacking Classifier    0.7791  0.6467   0.002   0.75  0.004  0.0028

# %% [markdown]
# # Finalize Model for Deployment

# %%
final_stack_soft = finalize_model(stack_soft)

# %% [markdown]
# # Predict on Unseen Data

# %%
unseen_predictions = predict_model(final_stack_soft, data=data_unseen)
unseen_predictions.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0     100000    2          2         2   23      0     -1     -1      0
# 1     380000    1          2         2   32     -1     -1     -1     -1
# 2     200000    2          2         1   32     -1     -1     -1     -1
# 3     200000    1          1         1   53      2      2      2      2
# 4     240000    1          1         2   41      1     -1     -1      0
#
#    PAY_5  ...  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  \
# 0      0  ...      567.0     380.0     601.0       0.0     581.0    1687.0
# 1     -1  ...    11873.0   21540.0   15138.0   24677.0   11851.0   11875.0
# 2      2  ...     3151.0    5818.0      15.0    9102.0      17.0    3165.0
# 3      2  ...   149531.0    6300.0    5500.0    5500.0    5500.0    5000.0
# 4      0  ...     1737.0    2622.0    3301.0       0.0     360.0    1737.0
#
#    PAY_AMT6  default  Label   Score
# 0    1542.0        0      0  0.3390
# ...

# %% [markdown]
# # Save the experiment

# %%
save_experiment('Experiment_123 08Feb2020')
# Out:
# Experiment Succesfully Saved

# %% [markdown]
# # Loading Saved Model

# %%
saved_experiment = load_experiment('Experiment_123 08Feb2020')
# Out:
#                                            Object
# 0                     Classification Setup Config
# 1                                  X_training Set
# 2                                  y_training Set
# 3                                      X_test Set
# 4                                      y_test Set
# ..                                            ...
# 56                         CalibratedClassifierCV
# 57              CalibratedClassifierCV Score Grid
# 58             Stacking Classifier (Single Layer)
# 59  Stacking Classifier (Single Layer) Score Grid
# 60              Final [GradientBoostingClassifier
#
# [61 rows x 1 columns]

# %%
final_stack_soft_loaded = saved_experiment[57]
final_stack_soft_loaded
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.8208  0.7692  0.3059  0.7248  0.4303  0.3442
# 1       0.8227  0.7804  0.2918  0.7574  0.4213  0.3401
# 2       0.8139  0.8061  0.2975  0.6818  0.4142  0.3233
# 3       0.8108  0.7508  0.3088  0.6527  0.4192  0.3231
# 4       0.8051  0.7573  0.2663  0.6438  0.3768  0.2841
# 5       0.8170  0.7851  0.3059  0.6968  0.4252  0.3355
# 6       0.8139  0.7529  0.3003  0.6795  0.4165  0.3250
# 7       0.8208  0.7861  0.3003  0.7310  0.4257  0.3408
# 8       0.8177  0.7530  0.3088  0.6987  0.4283  0.3386
# 9       0.8069  0.7830  0.2946  0.6380  0.4031  0.3061
# Mean    0.8150  0.7724  0.2980  0.6905  0.4161  0.3261
# SD      0.0057  0.0177  0.0119  0.0374  0.0151  0.0178

# %% [markdown]
# ### **Connect With Me in Linkedin** :- https://www.linkedin.com/in/dheerajkumar1997/
